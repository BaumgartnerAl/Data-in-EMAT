# %% [markdown]
# # Data in EMAT
# ## Fall 2021
# In this class I hope to:
# <ul>
#     <li>Further my coding abilities</li>
#     <li>Deepen my critical thinking skills</li>
#     <li>Develop a greater understanding of Data and its uses and ways to visualize and comprehend it</li>
# </ul>

# %% [markdown]
# ![Crab%20Bucket%204%20anim.jpg](attachment:Crab%20Bucket%204%20anim.jpg)

# %% [markdown]
# #### Variable Assignement

# %%
MyVariable = (1 + 2)

# %%
MyVariable
# Out:
# 3

# %% [markdown]
# #### For Loop

# %%
x = [0, 2, 4, 6, 8]
for i in x:
    print (i + 7)
# Out:
# 7
# 9
# 11
# 13
# 15

# %% [markdown]
# #### Print

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# #### Return

# %%
def sillything(x):
    return "silly" + str(x)

# %%
sillything('hi')
# Out:
# 'sillyhi'

# %%
j = sillything('dog')

# %%
j
# Out:
# 'sillydog'
